# %%
import os
from dotenv import load_dotenv
# Caminho raiz do projeto
load_dotenv()
os.listdir('../')
# Out:
# ['bronze_layer',
#  'etl_service.py',
#  'gold_layer',
#  'main.py',
#  'silver_layer',
#  'sources',
#  '__init__.py',
#  '__pycache__']

# %% [markdown]
# # Importações de Bibliotecas que serão utilizadas para ingestão de dados

# %%
import pandas as pd

# %% [markdown]
# # Carregamento e Análise da base a ser ingerida

# %%
data = pd.read_csv('../sources/dataset.csv', index_col='id')
data.head(3)
# Out:
#             price                                                url  \
# id
# 7309798041   2100  https://auburn.craigslist.org/cto/d/auburn-200...
# 7302327214  19000  https://auburn.craigslist.org/cto/d/auburn-uni...
# 7316878036  21950  https://bham.craigslist.org/ctd/d/birmingham-2...
#
#                 region                     region_url fuel  year manufacturer  \
# id
# 7309798041      auburn  https://auburn.craigslist.org  gas  2006       subaru
# 7302327214      auburn  https://auburn.craigslist.org  gas  2017       subaru
# 7316878036  birmingham    https://bham.craigslist.org  gas  2012       toyota
#
#                  model  condition    cylinders  ...  size       type  \
# id                                              ...
# 7309798041     impreza       fair  4 cylinders  ...   NaN  hatchback
# 7302327214    forester   like new  4 cylinders  ...   NaN        SUV
# 7316878036  tacoma 4x4  excellent  4 cylinders  ...   NaN      truck
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 82971 entries, 7309798041 to 7302353283
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         82971 non-null  int64
#  1   url           82971 non-null  object
#  2   region        82971 non-null  object
#  3   region_url    82971 non-null  object
#  4   fuel          82553 non-null  object
#  5   year          82971 non-null  int64
#  6   manufacturer  79518 non-null  object
#  7   model         82366 non-null  object
#  8   condition     57531 non-null  object
#  9   cylinders     82971 non-null  object
#  10  odometer      82971 non-null  int64
#  11  title_status  80274 non-null  object
#  12  transmission  82925 non-null  object
#  13  VIN           45290 non-null  object
#  14  drive         72389 non-null  object
#  15  size          39331 non-null  object
#  16  type          74090 non-null  object
#  17  paint_color   66621 non-null  object
# ...

# %%
data.describe()
# Out:
#               price          year      odometer  county           lat  \
# count  8.297100e+04  82971.000000  8.297100e+04     0.0  82971.000000
# mean   1.090852e+04   2002.790107  9.968908e+04     NaN     38.073258
# std    2.736743e+04    133.002241  1.714782e+05     NaN      8.067394
# min    0.000000e+00      0.000000  0.000000e+00     NaN    -84.122245
# 25%    4.650000e+03   2009.000000  5.065450e+04     NaN     34.645747
# 50%    8.500000e+03   2013.000000  9.300000e+04     NaN     39.433086
# 75%    1.490000e+04   2016.000000  1.329710e+05     NaN     42.471136
# max    6.995495e+06   2022.000000  1.000000e+07     NaN     64.947500
#
#                long
# count  82971.000000
# mean     -94.903715
# std       23.676977
# min     -159.719900
# 25%     -116.911017
# 50%      -89.984850
# 75%      -80.324600
# max       94.163200

# %%
data.shape
# Out:
# (82971, 25)
